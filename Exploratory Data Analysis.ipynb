# %%
# import python libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
file_path ='Diwali Sales Data.csv'

# %%
# import csv file
diwali_data = pd.read_csv(file_path, encoding= 'unicode_escape')

# %%
# Checking the Size of table
diwali_data.shape
# Out:
# (11250, 15)

# %%
diwali_data.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1001990      Bindu  P00118542      F     26-35   35               1
# 2  1001425     Sudevi  P00237842      M      0-17   16               0
# 3  1000588       Joni  P00057942      M     26-35   28               1
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1001132       Balk  P00018042      F     18-25   25               1
# 6  1002092   Shivangi  P00273442      F       55+   61               0
# 7  1003224     Kushal  P00205642      M     26-35   35               0
# 8  1003650      Ginny  P00031142      F     26-35   26               1
# 9  1003829   Harshita  P00200842      M     26-35   34               0
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
diwali_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11250 entries, 0 to 11249
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11250 non-null  int64
#  1   Cust_name         11250 non-null  object
#  2   Product_ID        11250 non-null  object
#  3   Gender            11250 non-null  object
#  4   Age Group         11250 non-null  object
#  5   Age               11250 non-null  int64
#  6   Marital_Status    11250 non-null  int64
#  7   State             11250 non-null  object
#  8   Zone              11250 non-null  object
#  9   Occupation        11250 non-null  object
#  10  Product_Category  11250 non-null  object
#  11  Orders            11250 non-null  int64
#  12  Amount            11238 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop unrelated/blank columns
diwali_data.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
diwali_data.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# drop null values
diwali_data.dropna(inplace=True)

# %%
diwali_data.shape
# Out:
# (11238, 13)

# %%
# change data type
diwali_data['Amount'] = diwali_data['Amount'].astype('int')

# %%
diwali_data['Amount'].dtypes
# Out:
# dtype('int32')

# %%
diwali_data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column
diwali_data.rename(columns= {'Marital_Status':'Shaadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1001990        Bindu  P00118542      F     26-35   35       1
# 2      1001425       Sudevi  P00237842      M      0-17   16       0
# 3      1000588         Joni  P00057942      M     26-35   28       1
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11245  1000695      Manning  P00296942      M     18-25   19       1
# 11246  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11247  1001209        Oshin  P00201342      F     36-45   40       0
# 11248  1004023       Noonan  P00059442      M     36-45   37       0
# 11249  1002744      Brumley  P00281742      F     18-25   19       0
#
#                   State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
diwali_data.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123800e+04  11238.000000    11238.000000  11238.000000  11238.000000
# mean   1.003004e+06     35.410393        0.420004      2.489589   9452.322032
# std    1.715981e+03     12.754433        0.493581      1.115006   5220.800607
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004427e+06     43.000000        1.000000      3.000000  12673.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
diwali_data[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11238.000000  11238.000000  11238.000000
# mean      35.410393      2.489589   9452.322032
# std       12.754433      1.115006   5220.800607
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12673.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # *Gender*

# %%
# plotting a bar chart for Gender and it's count

ax = sns.countplot(x = 'Gender',data = diwali_data)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for gender vs total amount

sales_gen = diwali_data.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
#  From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men

# %% [markdown]
# ### *Age*

# %%
ax = sns.countplot(data = diwali_data, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = diwali_data.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are of age group between 26-35 yrs female

# %% [markdown]
# ### *State*

# %%
# total number of orders from top 10 states

sales_state = diwali_data.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# total amount/sales from top 10 states

sales_state = diwali_data.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively

# %% [markdown]
# ### *Marital Status*

# %%
ax = sns.countplot(data = diwali_data, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = diwali_data.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are married (women) and they have high purchasing power

# %% [markdown]
# ### *Occupation*

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = diwali_data, x = 'Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = diwali_data.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector

# %% [markdown]
# ### *Product Category*

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = diwali_data, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = diwali_data.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category

# %%
sales_state = diwali_data.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
# top 10 most sold products (same thing as above)

fig1, ax1 = plt.subplots(figsize=(12,7))
diwali_data.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# Married women age group 26-35 yrs from UP,  Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'diwali_data' with columns 'Product_ID' and 'Orders'

fig1, ax1 = plt.subplots(figsize=(12, 7))
diwali_data.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')

plt.xlabel('Product ID')
plt.ylabel('Total Orders')
plt.title('Top 10 Most Sold Products')
plt.xticks(rotation=80)
plt.show()
